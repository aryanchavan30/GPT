# %%
with open(r"F:\LLM Projects\SebastianRaschka\GPTV1\data\Solar_Industries_India_Comprehensive_Analysis.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()
    
print("Total number of character:", len(raw_text))
print(raw_text[:99])
# Out:
# Total number of character: 138115
# # Solar Industries India Limited: A Comprehensive Analysis of India's Leading Explosives and Defens

# %%
import re

text = "Hello, world. This, is a test."
result = re.split(r'(\s)', text)

print(result)
# Out:
# ['Hello,', ' ', 'world.', ' ', 'This,', ' ', 'is', ' ', 'a', ' ', 'test.']

# %%
result = re.split(r'([,.]|\s)', text)

print(result)
# Out:
# ['Hello', ',', '', ' ', 'world', '.', '', ' ', 'This', ',', '', ' ', 'is', ' ', 'a', ' ', 'test', '.', '']

# %%
# Strip whitespace from each item and then filter out any empty strings.
result = [item for item in result if item.strip()]
print(result)
# Out:
# ['Hello', ',', 'world', '.', 'This', ',', 'is', 'a', 'test', '.']

# %%
text = "Hello, world. Is this-- a test?"

result = re.split(r'([,.:;?_!"()\']|--|\s)', text)
result = [item.strip() for item in result if item.strip()]
print(result)
# Out:
# ['Hello', ',', 'world', '.', 'Is', 'this', '--', 'a', 'test', '?']

# %%
preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', raw_text)
preprocessed = [item.strip() for item in preprocessed if item.strip()]
print(preprocessed[:30])
# Out:
# ['#', 'Solar', 'Industries', 'India', 'Limited', ':', 'A', 'Comprehensive', 'Analysis', 'of', 'India', "'", 's', 'Leading', 'Explosives', 'and', 'Defense', 'Manufacturer', '*Date', ':', 'November', '8', ',', '2025*', '##', 'Table', 'of', 'Contents', '1', '.']

# %%
print(len(preprocessed))
# Out:
# 20037

# %%
all_words = sorted(set(preprocessed))
vocab_size = len(all_words)

print(vocab_size)
# Out:
# 2965

# %%
vocab = {token:integer for integer,token in enumerate(all_words)}

# %%
for i, item in enumerate(vocab.items()):
    print(item)
    if i >= 50:
        break
# Out:
# ('"', 0)
# ('#', 1)
# ('##', 2)
# ('###', 3)
# ('####', 4)
# ('#business-segments-and-product-portfolio', 5)
# ('#company-overview-and-historical-background', 6)
# ('#conclusion', 7)
# ('#executive-summary', 8)
# ('#financial-performance-analysis', 9)
# ('#future-outlook-and-growth-prospects', 10)
# ('#global-presence-and-international-expansion', 11)
# ('#industry-analysis-and-market-dynamics', 12)
# ('#investment-perspective-and-valuation', 13)
# ('#management-and-corporate-governance', 14)
# ('#market-position-and-competitive-landscape', 15)
# ('#recent-developments-and-strategic-achievements', 16)
# ('#risks-and-challenges', 17)
# ('$6', 18)
# ('&', 19)
# ("'", 20)
# ('(', 21)
# (')', 22)
# ('*', 23)
# ('**', 24)
# ('**Acquisitions', 25)
# ('**Additive', 26)
# ('**Advanced', 27)
# ('**African', 28)
# ('**Albania**', 29)
# ('**Americas**', 30)
# ('**Ammonium', 31)
# ('**Ammunition', 32)
# ('**Andhra', 33)
# ('**Artificial', 34)
# ('**Ashish', 35)
# ('**Asia-Pacific', 36)
# ('**Audit', 37)
# ('**Automation', 38)
# ('**Automation**', 39)
# ('**Autonomous', 40)
# ('**Bhargavastra', 41)
# ('**Blockchain', 42)
# ('**Board', 43)
# ('**Bulk', 44)
# ('**Burkina', 45)
# ('**Business', 46)
# ('**Capacity', 47)
# ('**Capital', 48)
# ('**Carbon', 49)
# ('**Career', 50)

# %%
class SimpleTokenizerV1:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = {i:s for s,i in vocab.items()}
    
    def encode(self, text):
        preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)
                                
        preprocessed = [
            item.strip() for item in preprocessed if item.strip()
        ]
        ids = [self.str_to_int[s] for s in preprocessed]
        return ids
        
    def decode(self, ids):
        text = " ".join([self.int_to_str[i] for i in ids])
        # Replace spaces before the specified punctuations
        text = re.sub(r'\s+([,.?!"()\'])', r'\1', text)
        return text

# %%
tokenizer = SimpleTokenizerV1(vocab)

text = """"Solar Industries India Limited stands as one of India's most remarkable success stories in the industrial explosives and defense manufacturing sector. Founded in 1995 by visionary entrepreneur Satyanarayan Nandlalji Nuwal, the company has evolved from a small trading unit near Nagpur to become the world's fifth-largest explosives manufacturer and India's leading private sector defense producer <citation>13</citation>. 
"""
ids = tokenizer.encode(text)
print(ids)
# Out:
# [0, 1214, 854, 848, 927, 2699, 1448, 2323, 2314, 848, 20, 2607, 2277, 2560, 2737, 2713, 2063, 2783, 2088, 1890, 1427, 1708, 2228, 2621, 250, 783, 2063, 296, 1523, 2887, 1836, 1182, 1003, 1026, 244, 2783, 1589, 2006, 1859, 1959, 1355, 2669, 2814, 2853, 2295, 1002, 2801, 1479, 2783, 2922, 20, 2607, 1918, 1890, 2225, 1427, 848, 20, 2607, 2174, 2450, 2621, 1708, 2458, 426, 250]

# %%
tokenizer.decode(ids)
# Out:
# '" Solar Industries India Limited stands as one of India\' s most remarkable success stories in the industrial explosives and defense manufacturing sector. Founded in 1995 by visionary entrepreneur Satyanarayan Nandlalji Nuwal, the company has evolved from a small trading unit near Nagpur to become the world\' s fifth-largest explosives manufacturer and India\' s leading private sector defense producer <citation>13</citation>.'

# %%
tokenizer.decode(tokenizer.encode(text))
# Out:
# '" Solar Industries India Limited stands as one of India\' s most remarkable success stories in the industrial explosives and defense manufacturing sector. Founded in 1995 by visionary entrepreneur Satyanarayan Nandlalji Nuwal, the company has evolved from a small trading unit near Nagpur to become the world\' s fifth-largest explosives manufacturer and India\' s leading private sector defense producer <citation>13</citation>.'

# %%
all_tokens = sorted(list(set(preprocessed)))
all_tokens.extend(["<|endoftext|>", "<|unk|>"])

vocab = {token:integer for integer,token in enumerate(all_tokens)}

# %%
len(vocab.items())
# Out:
# 2967

# %%
for i, item in enumerate(list(vocab.items())[-5:]):
    print(item)
# Out:
# ('₹69', 2962)
# ('₹8', 2963)
# ('₹9', 2964)
# ('<|endoftext|>', 2965)
# ('<|unk|>', 2966)

# %%
class SimpleTokenizerV2:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = { i:s for s,i in vocab.items()}
    
    def encode(self, text):
        preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)
        preprocessed = [item.strip() for item in preprocessed if item.strip()]
        preprocessed = [
            item if item in self.str_to_int 
            else "<|unk|>" for item in preprocessed
        ]

        ids = [self.str_to_int[s] for s in preprocessed]
        return ids
        
    def decode(self, ids):
        text = " ".join([self.int_to_str[i] for i in ids])
        # Replace spaces before the specified punctuations
        text = re.sub(r'\s+([,.:;?!"()\'])', r'\1', text)
        return text

# %%
tokenizer = SimpleTokenizerV2(vocab)

text1 = "Hello, do you like tea?"
text2 = "In the sunlit terraces of the palace."

text = " <|endoftext|> ".join((text1, text2))

print(text)
# Out:
# Hello, do you like tea? <|endoftext|> In the sunlit terraces of the palace.

# %%
import importlib
import tiktoken

print("tiktoken version:", importlib.metadata.version("tiktoken"))
# Out:
# tiktoken version: 0.12.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = (
    "Hello, do you like tea? <|endoftext|> In the sunlit terraces"
     "of someunknownPlace."
)

integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})

print(integers)
# Out:
# [15496, 11, 466, 345, 588, 8887, 30, 220, 50256, 554, 262, 4252, 18250, 8812, 2114, 1659, 617, 34680, 27271, 13]

# %%
strings = tokenizer.decode(integers)

print(strings)
# Out:
# Hello, do you like tea? <|endoftext|> In the sunlit terracesof someunknownPlace.

# %%
with open(r"F:\LLM Projects\SebastianRaschka\GPTV1\data\Solar_Industries_India_Comprehensive_Analysis.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

enc_text = tokenizer.encode(raw_text)
print(len(enc_text))
# Out:
# 26843

# %%
enc_sample = enc_text[100:]
len(enc_sample)
# Out:
# 26743

# %%
context_size = 4
x = enc_sample[:context_size]
y = enc_sample[1:context_size+1]
print(f"X: {x}")
print(f"Y: {y}")
# Out:
# X: [685, 43621, 15193, 14691]
# Y: [43621, 15193, 14691, 16151]

# %%
for i in range(1, context_size+1):
    context = enc_sample[:i]
    desired = enc_sample[i]

    print(context, "---->", desired)
# Out:
# [685] ----> 43621
# [685, 43621] ----> 15193
# [685, 43621, 15193] ----> 14691
# [685, 43621, 15193, 14691] ----> 16151

# %%
for i in range(1, context_size+1):
    context = enc_sample[:i]
    desired = enc_sample[i]

    print(tokenizer.decode(context), "---->", tokenizer.decode([desired]))
# Out:
#  [ ----> Financial
#  [Financial ---->  Performance
#  [Financial Performance ---->  Analysis
#  [Financial Performance Analysis ----> ](

# %% [markdown]
# # 2.6 DataSet Class for GPT

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class GPTDatasetV1(Dataset):
    
    def __init__(self, text, tokenizer, max_length, stride):
        self.input_ids = []
        self.target_ids = []

        #Tokenizze the entier text
        token_ids = tokenizer.encode(text, allowed_special = {"<|endoftext|>"})
        assert len(token_ids) > max_length, "Number of tokenized inputs must at least be equal to max_length+1"

        # use a sliding window to chunk the book into overlapping sequences of max_length
        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i:i + max_length]
            target_chunk = token_ids[i + 1: i + max_length + 1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]

# %%
def create_dataloader_v1(txt , batch_size=4, max_length=256, stride=128,
                         shuffle=True, drop_last=True, num_workers=0):
    # Intilalize tokenizer
    tokenizer = tiktoken.get_encoding("gpt2")

    #create dataset
    dataset= GPTDatasetV1(txt, tokenizer, max_length, stride)

    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers
    )

    return dataloader

# %%
raw_text
# Out:
# '# Solar Industries India Limited: A Comprehensive Analysis of India\'s Leading Explosives and Defense Manufacturer\n\n \n*Date: November 8, 2025*\n\n## Table of Contents\n\n1. [Executive Summary](#executive-summary)\n2. [Company Overview and Historical Background](#company-overview-and-historical-background)\n3. [Business Segments and Product Portfolio](#business-segments-and-product-portfolio)\n4. [Financial Performance Analysis](#financial-performance-analysis)\n5. [Market Position and Competitive Landscape](#market-position-and-competitive-landscape)\n6. [Management and Corporate Governance](#management-and-corporate-governance)\n7. [Global Presence and International Expansion](#global-presence-and-international-expansion)\n8. [Recent Developments and Strategic Achievements](#recent-developments-and-strategic-achievements)\n9. [Industry Analysis and Market Dynamics](#industry-analysis-and-market-dynamics)\n10. [Future Outlook and Growth Prospects](#future-outlook-and-growth-prospects)\n11. [Investment Perspective and Valuation](#investment-perspective-and-valuation)\n12. [Risks and Challenges](#risks-and-challenges)\n13. [Conclusion](#conclusion)\n\n---\n\n## Executive Summary\n\nSolar Industries India Limited stands as one of India\'s most remarkable success stories in the industrial explosives and defense manufacturing sector. Founded in 1995 by visionary entrepreneur Satyanarayan Nandlalji Nuwal, the company has evolved from a small trading unit near Nagpur to become the world\'s fifth-largest explosives manufacturer and India\'s leading private sector defense producer <citation>13</citation>. \n\nAs of 2024-25, Solar Industries has achieved extraordinary milestones, including a market capitalization of over ₹1,00,000 crores, a significant defense order book of ₹11,000 crores, and the prestigious contract for manufacturing Pinaka rockets worth ₹6,084 crores <citation>13</citation>. The company\'s revenue has grown exponentially from ₹22,784 million in FY20 to ₹61,140 million in FY24, representing a remarkable five-year CAGR of 28% <citation>3</citation>.\n\nThe company\'s success stems from its strategic focus on two core business segments: industrial explosives and defense manufacturing. In the industrial explosives segment, Solar Industries maintains its position as India\'s largest manufacturer and exporter, serving over 200 customers across 82+ countries <citation>41</citation>. Their defense segment has gained remarkable momentum, marked by the successful delivery of 100% indigenous 30mm ammunition to the Indian Navy and the development of cutting-edge systems like the Nagastra-1 loitering munition and Bhargavastra counter-drone system <citation>13</citation>.\n\nSolar Industries\' financial performance demonstrates exceptional operational efficiency and profitability. The company achieved a net profit margin of 14.4% in FY24, up from 11.7% in FY23, while maintaining strong return metrics including ROE of 26.5% and ROCE of 32.7% <citation>3</citation>. The company\'s cash flow from operations increased dramatically by 114.2% YoY to ₹14,060 million in FY24, indicating strong operational performance and working capital management <citation>3</citation>.\n\nThe Indian defense manufacturing sector is experiencing unprecedented growth, with the government setting an ambitious target of ₹50,000 crores in defense exports by 2029 <citation>51</citation>. Private sector participation has increased significantly, reaching 22.56% of total defense production in FY 2024-25 <citation>55</citation>. This environment provides substantial opportunities for companies like Solar Industries to capitalize on the growing demand for indigenous defense equipment and systems.\n\nFrom an investment perspective, Solar Industries presents a compelling opportunity backed by strong fundamentals, strategic positioning in high-growth sectors, and a robust order book. The company\'s commitment to innovation, quality, and safety, combined with its  ...

# %%
dataloader = create_dataloader_v1(
    raw_text, batch_size=1, max_length=4, stride=1, shuffle=False
)

data_iter = iter(dataloader)
first_batch = next(data_iter)
print(first_batch)
# Out:
# [tensor([[    2, 12347, 20171,  3794]]), tensor([[12347, 20171,  3794, 15302]])]

# %%
second_batch = next(data_iter)
print(second_batch)
# Out:
# [tensor([[12347, 20171,  3794, 15302]]), tensor([[20171,  3794, 15302,    25]])]

# %%
dataloader = create_dataloader_v1(
    raw_text, batch_size=1, max_length=4, stride=4, shuffle=False
)

data_iter = iter(dataloader)
first_batch = next(data_iter)
print(first_batch)
# Out:
# [tensor([[    2, 12347, 20171,  3794]]), tensor([[12347, 20171,  3794, 15302]])]

# %%
second_batch = next(data_iter)
print(second_batch)
# Out:
# [tensor([[15302,    25,   317, 40917]]), tensor([[   25,   317, 40917, 14691]])]

# %%
dataloader = create_dataloader_v1(
    raw_text, batch_size=8, max_length=4, stride=4, shuffle=False
)

data_iter = iter(dataloader)
inputs, target = next(data_iter)
print("Input:- \n",inputs)
print("Target:- \n",target)
# Out:
# Input:-
#  tensor([[    2, 12347, 20171,  3794],
#         [15302,    25,   317, 40917],
#         [14691,   286,  3794,   338],
#         [43225, 33022,  1083,   290],
#         [ 5947, 40218,   628,   220],
#         [  198,     9, 10430,    25],
#         [ 3389,   807,    11, 32190],
#         [    9,   198,   198,  2235]])
# Target:-
#  tensor([[12347, 20171,  3794, 15302],
#         [   25,   317, 40917, 14691],
#         [  286,  3794,   338, 43225],
#         [33022,  1083,   290,  5947],
#         [40218,   628,   220,   198],
#         [    9, 10430,    25,  3389],
#         [  807,    11, 32190,     9],
#         [  198,   198,  2235,  8655]])

# %% [markdown]
# # 2.7 Creating token Embeddings

# %%
inputs_ids = torch.tensor([2,4,3,6])

# %%
vocab_size = 6
output_dim = 3

embedding_layer = torch.nn.Embedding(vocab_size, output_dim) #This would result in a 6x3 weight matrix
